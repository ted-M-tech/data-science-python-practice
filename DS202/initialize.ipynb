# %% [markdown]
# ---

# %%
# !pip install psycopg2

# %%
import psycopg2

# dummy info
conn = psycopg2.connect(
    dbname = 'ds202',
    user = 'admin',
    password = 'admin',
    host = 'localhost',
    port = '5432' )

# %%
# cursor object to execute the sql command
cur = conn.cursor()

cur.execute("SELECT * FROM movies LIMIT 3;")

# fetch all the records from the executed query
rows = cur.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'The Shawshank Redemption', 'Drama', 1999)
# (2, 'The Godfather', 'Drama', 1987)
# (3, 'The Dark Knight', 'Drama', 1993)

# %%
print(rows)
# Out:
# [(1, 'The Shawshank Redemption', 'Drama', 1999), (2, 'The Godfather', 'Drama', 1987), (3, 'The Dark Knight', 'Drama', 1993)]

# %%
import pandas as pd

df = pd.read_sql_query("SELECT * FROM movies LIMIT 3;", conn)

df
# Out:
# /var/folders/11/_4nf9vcd381d35kpvnpx8jph0000gn/T/ipykernel_90286/2568884469.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("SELECT * FROM movies LIMIT 3;", conn)
#    movie_id                     title  genre  release_year
# 0         1  The Shawshank Redemption  Drama          1999
# 1         2             The Godfather  Drama          1987
# 2         3           The Dark Knight  Drama          1993
